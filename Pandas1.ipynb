# %%
import pandas as pd
import os
import numpy as np

# %%
# pd.read_csv("D:\Training\PGA_A\PGA23\ML\EDA\Churn_Modelling.csv")
# pd.read_csv("D:\Training\PGA_A\PGA23\ML\EDA\Churn_Modelling.csv")
# pd.read_csv("D:\\Training\\PGA_A\\PGA23\\ML\\EDA\\Churn_Modelling.csv")
pd.read_csv("D:/Training/PGA_A/PGA23/ML/EDA/Churn_Modelling.csv")
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df=pd.read_csv(r"D:\Training\PGA_A\PGA23\ML\EDA\Churn_Modelling.csv")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Archit\\ATraining\\PGA23\\Python\\Packages_EDA'

# %%
os.chdir(r"D:\Training\PGA_A\PGA23\ML\EDA")

# %%
os.getcwd()
# Out:
# 'D:\\Training\\PGA_A\\PGA23\\ML\\EDA'

# %%
os.listdir()
# Out:
# ['Churn_Modelling.csv']

# %%
df1=pd.read_csv("Churn_Modelling.csv")

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df1.head(7)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# ...

# %%
df1.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df1.ndim
# Out:
# 2

# %%
df1.shape
# Out:
# (10000, 14)

# %%
df1.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ### New Columns add/delete

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df1["NewCol1"]=0

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  NewCol1
# 0        101348.88       1        0
# 1        112542.58       0        0
# 2        113931.57       1        0
# ...

# %%
df1["NewCol2"]=np.nan

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  NewCol1  NewCol2
# 0        101348.88       1        0      NaN
# 1        112542.58       0        0      NaN
# ...

# %%
df1["Salary INR"]=df1["EstimatedSalary"]*77

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  NewCol1  NewCol2  Salary INR
# 0        101348.88       1        0      NaN  7803863.76
# ...

# %%
df1["Balance_Salary"]=df1["Balance"]+df1["EstimatedSalary"]

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  NewCol1  NewCol2  Salary INR  Balance_Salary
# 0        101348.88       1        0      NaN  7803863.76       101348.88
# ...

# %%
df1["EstimatedSalary"].describe()  # Summary
# Out:
# count     10000.000000
# mean     100090.239881
# std       57510.492818
# min          11.580000
# 25%       51002.110000
# 50%      100193.915000
# 75%      149388.247500
# max      199992.480000
# Name: EstimatedSalary, dtype: float64

# %%
df1["income_group1"]=np.where(df1["EstimatedSalary"]<50000, "Low income", "High Income")

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  NewCol1  NewCol2  Salary INR  Balance_Salary  \
# 0        101348.88       1        0      NaN  7803863.76       101348.88
# ...

# %%
df1["income_group1"].value_counts()  # Freq Distribution
# Out:
# High Income    7547
# Low income     2453
# Name: income_group1, dtype: int64

# %%
df1["income_group2"]=np.where(df1["EstimatedSalary"]<50000,"Low",np.where(df1["EstimatedSalary"]>100000, "High", "Median"))

# %%
df1["income_group2"].value_counts()
# Out:
# High      5010
# Median    2537
# Low       2453
# Name: income_group2, dtype: int64

# %%
def cat(x):
    if x <50000:
        return "Low"
    elif x>100000:
        return "High"
    else:
        return "Median"

# %%
# def cat(x):
#     if x <50000:
#         return "Low"
#     elif x>=50000 and x<100000:
#         return "median"
#     else:
#         return "High"

# %%
df1["income_group_cat"]=df1["EstimatedSalary"].apply(cat)

# %%
df1["income_group_cat"].value_counts()
# Out:
# High      5010
# Median    2537
# Low       2453
# Name: income_group_cat, dtype: int64

# %% [markdown]
# #### Droping the columns

# %%
df1.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'NewCol1', 'NewCol2',
#        'Salary INR', 'Balance_Salary', 'income_group1', 'income_group2',
#        'income_group_cat'],
#       dtype='object')

# %%
df1.drop(columns=['NewCol1',"NewCol2" ], inplace=True)   # df1= df1.drop(columns=['NewCol1',"NewCol2" ])

# %%
df1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Subsetting of data

# %% [markdown]
# #### Column based

# %%
df1.Surname
# Out:
# 0        Hargrave
# 1            Hill
# 2            Onio
# 3            Boni
# 4        Mitchell
#           ...
# 9995     Obijiaku
# 9996    Johnstone
# 9997          Liu
# 9998    Sabbatini
# 9999       Walker
# Name: Surname, Length: 10000, dtype: object

# %%
df1["Surname"]
# Out:
# 0        Hargrave
# 1            Hill
# 2            Onio
# 3            Boni
# 4        Mitchell
#           ...
# 9995     Obijiaku
# 9996    Johnstone
# 9997          Liu
# 9998    Sabbatini
# 9999       Walker
# Name: Surname, Length: 10000, dtype: object

# %%
df1.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Salary INR',
#        'Balance_Salary', 'income_group1', 'income_group2', 'income_group_cat'],
#       dtype='object')

# %%
df1[["Surname"]]
# Out:
#         Surname
# 0      Hargrave
# 1          Hill
# 2          Onio
# 3          Boni
# 4      Mitchell
# ...         ...
# 9995   Obijiaku
# 9996  Johnstone
# 9997        Liu
# 9998  Sabbatini
# 9999     Walker
#
# [10000 rows x 1 columns]

# %%
df1[["Surname","Tenure", "Balance" ]].head()
# Out:
#     Surname  Tenure    Balance
# 0  Hargrave       2       0.00
# 1      Hill       1   83807.86
# 2      Onio       8  159660.80
# 3      Boni       1       0.00
# 4  Mitchell       2  125510.82

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# 0        101348.88       1  7803863.76       101348.88   High Income
# ...

# %%
# df1.iloc[Row index, column index]
df1.iloc[:, 3:7]
# Out:
#       CreditScore Geography  Gender  Age
# 0             619    France  Female   42
# 1             608     Spain  Female   41
# 2             502    France  Female   42
# 3             699    France  Female   39
# 4             850     Spain  Female   43
# ...           ...       ...     ...  ...
# 9995          771    France    Male   39
# 9996          516    France    Male   35
# 9997          709    France  Female   36
# 9998          772   Germany    Male   42
# 9999          792    France  Female   28
#
# [10000 rows x 4 columns]

# %%
df1.iloc[:,[3, 5,8,11]]
# Out:
#       CreditScore  Gender    Balance  IsActiveMember
# 0             619  Female       0.00               1
# 1             608  Female   83807.86               1
# 2             502  Female  159660.80               0
# 3             699  Female       0.00               0
# 4             850  Female  125510.82               1
# ...           ...     ...        ...             ...
# 9995          771    Male       0.00               0
# 9996          516    Male   57369.61               1
# 9997          709  Female       0.00               1
# 9998          772    Male   75075.31               0
# 9999          792  Female  130142.79               0
#
# [10000 rows x 4 columns]

# %%
df1.iloc[:10,:]
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df1.iloc[2:5,[4,6,10]]
# Out:
#   Geography  Age  HasCrCard
# 2    France   42          1
# 3    France   39          0
# 4     Spain   43          1

# %%
df1.iloc[[9, 99, 999]]  # df1.iloc[[9,99,999], :]
# Out:
#      RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 9           10    15592389       H?          684    France    Male   27
# 99         100    15633059  Fanucci          413    France    Male   34
# 999       1000    15787772   Hansen          759    France  Female   38
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9         2  134603.88              1          1               1
# 99        9       0.00              2          0               0
# 999       1  104091.29              1          0               0
#
#      EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# 9           71725.73       0  5522881.21       206329.61   High Income
# 99           6534.18       0   503131.86         6534.18    Low income
# 999         91561.91       0  7050267.07       195653.20   High Income
#
#     income_group2 income_group_cat
# 9          Median           Median
# 99            Low              Low
# ...

# %%
df1.iloc[[2,6,0],[2,4,7,9,1]]
# Out:
#     Surname Geography  Tenure  NumOfProducts  CustomerId
# 2      Onio    France       8              3    15619304
# 6  Bartlett    France       7              2    15592531
# 0  Hargrave    France       2              1    15634602

# %%
# df1.loc[Row labels,columns labels]
df1.loc[:, ["Surname", "Tenure"]].head()
# Out:
#     Surname  Tenure
# 0  Hargrave       2
# 1      Hill       1
# 2      Onio       8
# 3      Boni       1
# 4  Mitchell       2

# %%
df1.loc[:10,:"Tenure"]
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602  Hargrave          619    France  Female   42
# 1           2    15647311      Hill          608     Spain  Female   41
# 2           3    15619304      Onio          502    France  Female   42
# 3           4    15701354      Boni          699    France  Female   39
# 4           5    15737888  Mitchell          850     Spain  Female   43
# 5           6    15574012       Chu          645     Spain    Male   44
# 6           7    15592531  Bartlett          822    France    Male   50
# 7           8    15656148    Obinna          376   Germany  Female   29
# 8           9    15792365        He          501    France    Male   44
# 9          10    15592389        H?          684    France    Male   27
# 10         11    15767821    Bearce          528    France    Male   31
#
#     Tenure
# 0        2
# 1        1
# 2        8
# 3        1
# 4        2
# 5        8
# 6        7
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df1.set_index(["CustomerId"], inplace=True)

# %%
df1.head()
# Out:
#             RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France  Female   42       2
# 15647311            2      Hill          608     Spain  Female   41       1
# 15619304            3      Onio          502    France  Female   42       8
# 15701354            4      Boni          699    France  Female   39       1
# 15737888            5  Mitchell          850     Spain  Female   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# CustomerId
# ...

# %%
df1.index
# Out:
# Int64Index([15634602, 15647311, 15619304, 15701354, 15737888, 15574012,
#             15592531, 15656148, 15792365, 15592389,
#             ...
#             15798964, 15769959, 15657105, 15569266, 15719294, 15606229,
#             15569892, 15584532, 15682355, 15628319],
#            dtype='int64', name='CustomerId', length=10000)

# %%
df1.loc[[15701354, 15657105],]
# Out:
#             RowNumber      Surname  CreditScore Geography  Gender  Age  \
# CustomerId
# 15701354            4         Boni          699    France  Female   39
# 15657105         9993  Chukwualuka          726     Spain    Male   36
#
#             Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15701354         1      0.0              2          0               0
# 15657105         2      0.0              1          1               0
#
#             EstimatedSalary  Exited   Salary INR  Balance_Salary  \
# CustomerId
# 15701354           93826.63       0   7224650.51        93826.63
# 15657105          195192.40       0  15029814.80       195192.40
#
#            income_group1 income_group2 income_group_cat
# CustomerId
# 15701354     High Income        Median           Median
# 15657105     High Income          High             High

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#       CustomerId  RowNumber    Surname  CreditScore Geography  Gender  Age  \
# 0       15634602          1   Hargrave          619    France  Female   42
# 1       15647311          2       Hill          608     Spain  Female   41
# 2       15619304          3       Onio          502    France  Female   42
# 3       15701354          4       Boni          699    France  Female   39
# 4       15737888          5   Mitchell          850     Spain  Female   43
# ...          ...        ...        ...          ...       ...     ...  ...
# 9995    15606229       9996   Obijiaku          771    France    Male   39
# 9996    15569892       9997  Johnstone          516    France    Male   35
# 9997    15584532       9998        Liu          709    France  Female   36
# 9998    15682355       9999  Sabbatini          772   Germany    Male   42
# 9999    15628319      10000     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### conditional subsetting

# %%
df1
# Out:
#       CustomerId  RowNumber    Surname  CreditScore Geography  Gender  Age  \
# 0       15634602          1   Hargrave          619    France  Female   42
# 1       15647311          2       Hill          608     Spain  Female   41
# 2       15619304          3       Onio          502    France  Female   42
# 3       15701354          4       Boni          699    France  Female   39
# 4       15737888          5   Mitchell          850     Spain  Female   43
# ...          ...        ...        ...          ...       ...     ...  ...
# 9995    15606229       9996   Obijiaku          771    France    Male   39
# 9996    15569892       9997  Johnstone          516    France    Male   35
# 9997    15584532       9998        Liu          709    France  Female   36
# 9998    15682355       9999  Sabbatini          772   Germany    Male   42
# 9999    15628319      10000     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df1[df1["Gender"]=="Male"]
# Out:
#       CustomerId  RowNumber      Surname  CreditScore Geography Gender  Age  \
# 5       15574012          6          Chu          645     Spain   Male   44
# 6       15592531          7     Bartlett          822    France   Male   50
# 8       15792365          9           He          501    France   Male   44
# 9       15592389         10           H?          684    France   Male   27
# 10      15767821         11       Bearce          528    France   Male   31
# ...          ...        ...          ...          ...       ...    ...  ...
# 9992    15657105       9993  Chukwualuka          726     Spain   Male   36
# 9993    15569266       9994       Rahman          644    France   Male   28
# 9995    15606229       9996     Obijiaku          771    France   Male   39
# 9996    15569892       9997    Johnstone          516    France   Male   35
# 9998    15682355       9999    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df2_high_credit=df1[df1["CreditScore"]>=750]

# %%
df2_high_credit.head()
# Out:
#     CustomerId  RowNumber   Surname  CreditScore Geography  Gender  Age  \
# 4     15737888          5  Mitchell          850     Spain  Female   43
# 6     15592531          7  Bartlett          822    France    Male   50
# 24    15625047         25       Yen          846    France  Female   38
# 26    15736816         27     Young          756   Germany    Male   36
# 37    15729599         38   Lorenzo          804     Spain    Male   33
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4        2  125510.82              1          1               1
# 6        7       0.00              2          1               1
# 24       5       0.00              1          1               1
# 26       2  136815.64              1          1               1
# 37       7   76548.60              1          0               1
#
#     EstimatedSalary  Exited   Salary INR  Balance_Salary income_group1  \
# 4          79084.10       0   6089475.70       204594.92   High Income
# ...

# %%
df_cred_female=df1[(df1["CreditScore"]>=750) & (df1["Gender"]=="Female")]

# %%
df_cred_female.head()
# Out:
#     CustomerId  RowNumber   Surname  CreditScore Geography  Gender  Age  \
# 4     15737888          5  Mitchell          850     Spain  Female   43
# 24    15625047         25       Yen          846    France  Female   38
# 43    15755196         44    Lavine          834    France  Female   49
# 45    15754849         46     Tyler          776   Germany  Female   32
# 46    15602280         47    Martin          829   Germany  Female   27
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4        2  125510.82              1          1               1
# 24       5       0.00              1          1               1
# 43       2  131394.56              1          0               0
# 45       4  109421.13              2          1               1
# 46       9  112045.67              1          1               1
#
#     EstimatedSalary  Exited   Salary INR  Balance_Salary income_group1  \
# 4          79084.10       0   6089475.70       204594.92   High Income
# ...

# %%
df1["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df1["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df1[(df1["Geography"]=="Spain") | (df1["Geography"]=="France")].head()
# Out:
#    CustomerId  RowNumber   Surname  CreditScore Geography  Gender  Age  \
# 0    15634602          1  Hargrave          619    France  Female   42
# 1    15647311          2      Hill          608     Spain  Female   41
# 2    15619304          3      Onio          502    France  Female   42
# 3    15701354          4      Boni          699    France  Female   39
# 4    15737888          5  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# 0        101348.88       1  7803863.76       101348.88   High Income
# ...

# %%
df1[df1["Geography"].isin(["Spain", "France"])].head()
# Out:
#    CustomerId  RowNumber   Surname  CreditScore Geography  Gender  Age  \
# 0    15634602          1  Hargrave          619    France  Female   42
# 1    15647311          2      Hill          608     Spain  Female   41
# 2    15619304          3      Onio          502    France  Female   42
# 3    15701354          4      Boni          699    France  Female   39
# 4    15737888          5  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# 0        101348.88       1  7803863.76       101348.88   High Income
# ...

# %%
cond1=df1["Balance"]<=0
df1.loc[cond1, ["CustomerId", "Surname", "Balance"]].head()
# Out:
#     CustomerId   Surname  Balance
# 0     15634602  Hargrave      0.0
# 3     15701354      Boni      0.0
# 6     15592531  Bartlett      0.0
# 11    15737173   Andrews      0.0
# 12    15632264       Kay      0.0

# %% [markdown]
# ### sorting of data

# %%
df1.sort_values(by=["Geography"])  # By Default = Ascending order
# Out:
#       CustomerId  RowNumber     Surname  CreditScore Geography  Gender  Age  \
# 0       15634602          1    Hargrave          619    France  Female   42
# 5577    15726087       5578       Ch'in          592    France  Female   62
# 5575    15782879       5576        Lang          656    France    Male   40
# 5573    15628893       5574       Power          681    France    Male   29
# 5572    15613140       5573      Mellor          565    France    Male   34
# ...          ...        ...         ...          ...       ...     ...  ...
# 6611    15715199       6612     Estrada          568     Spain    Male   27
# 1712    15744983       1713    Burgmann          712     Spain    Male   47
# 1710    15567993       1711      Palmer          828     Spain    Male   28
# 6537    15782364       6538       Bevan          521     Spain  Female   39
# 4999    15710408       5000  Cunningham          584     Spain  Female   38
#
# ...

# %%
df1.sort_values(by=["Geography"], ascending=False)
# Out:
#       CustomerId  RowNumber    Surname  CreditScore Geography  Gender  Age  \
# 6666    15798709       6667       Gill          588     Spain    Male   32
# 8953    15592925       8954   Giordano          711     Spain    Male   42
# 2145    15639322       2146      Grave          633     Spain    Male   33
# 4852    15574137       4853      Ch'in          687     Spain    Male   35
# 2148    15811842       2149  Artemyeva          630     Spain    Male   26
# ...          ...        ...        ...          ...       ...     ...  ...
# 4439    15696539       4440       Wade          613    France  Female   21
# 4437    15779522       4438     Efimov          736    France  Female   24
# 4436    15664498       4437  Golovanov          508    France    Male   26
# 4433    15724099       4434    Udinese          674    France    Male   26
# 9999    15628319      10000     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df1.sort_values(by=["Geography", "Balance"], ascending=[True, False])
# Out:
#       CustomerId  RowNumber      Surname  CreditScore Geography  Gender  Age  \
# 3280    15715622       3281       To Rot          583    France  Female   57
# 1533    15769818       1534        Moore          850    France  Female   37
# 2709    15780212       2710          Mao          592    France    Male   37
# 8702    15690589       8703      Udinesi          541    France    Male   37
# 520     15671256        521    Macartney          850    France  Female   35
# ...          ...        ...          ...          ...       ...     ...  ...
# 9955    15611338       9956    Kashiwagi          714     Spain    Male   29
# 9961    15566543       9962     Aldridge          573     Spain    Male   44
# 9962    15594612       9963        Flynn          702     Spain    Male   44
# 9989    15605622       9990     McMillan          841     Spain    Male   28
# 9992    15657105       9993  Chukwualuka          726     Spain    Male   36
#
# ...

# %%
df1.columns
# Out:
# Index(['CustomerId', 'RowNumber', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Salary INR',
#        'Balance_Salary', 'income_group1', 'income_group2', 'income_group_cat'],
#       dtype='object')

# %% [markdown]
# ### Rename of Columns

# %%
df1.rename(columns={"Age":"age_in_year", "Balance":"TotalAmountBank"}, inplace=True)

# %%
df1
# Out:
#       CustomerId  RowNumber    Surname  CreditScore Geography  Gender  \
# 0       15634602          1   Hargrave          619    France  Female
# 1       15647311          2       Hill          608     Spain  Female
# 2       15619304          3       Onio          502    France  Female
# 3       15701354          4       Boni          699    France  Female
# 4       15737888          5   Mitchell          850     Spain  Female
# ...          ...        ...        ...          ...       ...     ...
# 9995    15606229       9996   Obijiaku          771    France    Male
# 9996    15569892       9997  Johnstone          516    France    Male
# 9997    15584532       9998        Liu          709    France  Female
# 9998    15682355       9999  Sabbatini          772   Germany    Male
# 9999    15628319      10000     Walker          792    France  Female
#
#       age_in_year  Tenure  TotalAmountBank  NumOfProducts  HasCrCard  \
# ...

# %% [markdown]
# ### Duplicates

# %%
df1.duplicated().sum()  # Entire Row
# Out:
# 0

# %%
df1["CustomerId"].duplicated().sum()  # CustomerId
# Out:
# 0

# %% [markdown]
# #### dataframe creation and duplicates Check

# %%
mydf=pd.DataFrame({"ID":[10, 11, 12, 11,14,15, 11],
             "Name":["Harry", "Dawn", "Gini", "Dawn", "Gosawmy", "John", "Dawn"],
                  "marks":[89, 75, 67, 75, 60, 81,86]})

# %%
mydf
# Out:
#    ID     Name  marks
# 0  10    Harry     89
# 1  11     Dawn     75
# 2  12     Gini     67
# 3  11     Dawn     75
# 4  14  Gosawmy     60
# 5  15     John     81
# 6  11     Dawn     86

# %%
mydf.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
mydf["ID"].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# Name: ID, dtype: bool

# %%
mydf[["ID", "Name"]].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
mydf[~mydf.duplicated()]   # Removing duplicates on row level
# Out:
#    ID     Name  marks
# 0  10    Harry     89
# 1  11     Dawn     75
# 2  12     Gini     67
# 4  14  Gosawmy     60
# 5  15     John     81
# 6  11     Dawn     86

# %%
mydf[mydf[["ID", "Name"]].duplicated()]  # Duplicated values
# Out:
#    ID  Name  marks
# 3  11  Dawn     75
# 6  11  Dawn     86

# %%
mydf.drop_duplicates()  # Dropping duplictaed on row level
# Out:
#    ID     Name  marks
# 0  10    Harry     89
# 1  11     Dawn     75
# 2  12     Gini     67
# 4  14  Gosawmy     60
# 5  15     John     81
# 6  11     Dawn     86

# %%
mydf.drop_duplicates(subset=["ID"], keep='first')
# Out:
#    ID     Name  marks
# 0  10    Harry     89
# 1  11     Dawn     75
# 2  12     Gini     67
# 4  14  Gosawmy     60
# 5  15     John     81

# %% [markdown]
# ### missing value

# %%
df1.isnull().sum()
# Out:
# CustomerId          0
# RowNumber           0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# age_in_year         0
# Tenure              0
# TotalAmountBank     0
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# Salary INR          0
# Balance_Salary      0
# income_group1       0
# income_group2       0
# income_group_cat    0
# dtype: int64

# %%
mydf=pd.DataFrame({"ID":[10, 11, 12, 11,14,15, 11],
             "Name":["Harry", "Dawn", "Gini", "Dawn", np.nan, "John", "Dawn"],
                  "marks":[89, 75, np.nan, 75, np.nan, 81,86]})

# %%
mydf
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini    NaN
# 3  11   Dawn   75.0
# 4  14    NaN    NaN
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %%
mydf.isnull()
# Out:
#       ID   Name  marks
# 0  False  False  False
# 1  False  False  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True   True
# 5  False  False  False
# 6  False  False  False

# %%
mydf.isnull().sum()
# Out:
# ID       0
# Name     1
# marks    2
# dtype: int64

# %%
mydf.dropna()
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 3  11   Dawn   75.0
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %%
mydf.fillna(value=88)  # Filling a value
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini   88.0
# 3  11   Dawn   75.0
# 4  14     88   88.0
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %%
  mydf.fillna(method="ffill")
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini   75.0
# 3  11   Dawn   75.0
# 4  14   Dawn   75.0
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %%
mydf
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini    NaN
# 3  11   Dawn   75.0
# 4  14    NaN    NaN
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %%
mydf.fillna(method="bfill")
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini   75.0
# 3  11   Dawn   75.0
# 4  14   John   81.0
# 5  15   John   81.0
# 6  11   Dawn   86.0

# %% [markdown]
# ### Summary

# %%
df1.columns
# Out:
# Index(['CustomerId', 'RowNumber', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'age_in_year', 'Tenure', 'TotalAmountBank', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited',
#        'Salary INR', 'Balance_Salary', 'income_group1', 'income_group2',
#        'income_group_cat'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerId        10000 non-null  int64
#  1   RowNumber         10000 non-null  int64
#  2   Surname           10000 non-null  object
#  3   CreditScore       10000 non-null  int64
#  4   Geography         10000 non-null  object
#  5   Gender            10000 non-null  object
#  6   age_in_year       10000 non-null  int64
#  7   Tenure            10000 non-null  int64
#  8   TotalAmountBank   10000 non-null  float64
#  9   NumOfProducts     10000 non-null  int64
#  10  HasCrCard         10000 non-null  int64
#  11  IsActiveMember    10000 non-null  int64
#  12  EstimatedSalary   10000 non-null  float64
#  13  Exited            10000 non-null  int64
#  14  Salary INR        10000 non-null  float64
#  15  Balance_Salary    10000 non-null  float64
# ...

# %%
df1.dtypes
# Out:
# CustomerId            int64
# RowNumber             int64
# Surname              object
# CreditScore           int64
# Geography            object
# Gender               object
# age_in_year           int64
# Tenure                int64
# TotalAmountBank     float64
# NumOfProducts         int64
# HasCrCard             int64
# IsActiveMember        int64
# EstimatedSalary     float64
# Exited                int64
# Salary INR          float64
# Balance_Salary      float64
# income_group1        object
# income_group2        object
# income_group_cat     object
# dtype: object

# %%
df1.dtypes[df1.dtypes=="object"]
# Out:
# Surname             object
# Geography           object
# Gender              object
# income_group1       object
# income_group2       object
# income_group_cat    object
# dtype: object

# %%
list(df1["Surname"].unique())
# Out:
# ['Hargrave',
#  'Hill',
#  'Onio',
#  'Boni',
#  'Mitchell',
#  'Chu',
#  'Bartlett',
#  'Obinna',
#  'He',
#  'H?',
#  'Bearce',
#  'Andrews',
#  'Kay',
#  'Chin',
#  'Scott',
#  'Goforth',
#  'Romeo',
#  'Henderson',
#  'Muldrow',
#  'Hao',
#  'McDonald',
#  'Dellucci',
#  'Gerasimov',
#  'Mosman',
#  'Yen',
#  'Maclean',
#  'Young',
#  'Nebechi',
#  'McWilliams',
#  'Lucciano',
#  'Azikiwe',
#  'Odinakachukwu',
#  'Sanderson',
#  'Maggard',
#  'Clements',
#  'Lombardo',
#  'Watson',
#  'Lorenzo',
#  'Armstrong',
#  'Cameron',
#  'Hsiao',
#  'Clarke',
#  'Osborne',
#  'Lavine',
#  'Bianchi',
#  'Tyler',
#  'Martin',
#  'Okagbue',
#  'Yin',
#  'Buccho',
#  'Chidiebele',
#  'Trevisani',
#  "O'Brien",
#  'Parkhill',
#  'Yoo',
#  'Phillipps',
#  'Tsao',
#  'Endrizzi',
#  "T'ien",
#  'Velazquez',
#  'Hunter',
#  'Clark',
#  'Jeffrey',
#  'Pirozzi',
#  'Jackson',
#  'Hammond',
#  'Brownless',
#  'Chibugo',
#  'Glauert',
#  'Pisano',
#  'Konovalova',
#  'McKee',
#  'Palermo',
# ...

# %%
df1["Surname"].nunique()
# Out:
# 2932

# %%
df1["Surname"].value_counts()
# Out:
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64

# %%
df1["Surname"].value_counts(dropna=False)
# Out:
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64

# %%
df1["Geography"].value_counts(dropna=False, normalize=True)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %%
df1["Geography"].value_counts(dropna=False)
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df1["Geography"].mode()
# Out:
# 0    France
# Name: Geography, dtype: object

# %%
df1["TotalAmountBank"].min()
# Out:
# 0.0

# %%
df1["TotalAmountBank"].max()
# Out:
# 250898.09

# %%
df1["TotalAmountBank"].mean()
# Out:
# 76485.88928799961

# %%
df1["TotalAmountBank"].std()
# Out:
# 62397.40520238623

# %%
df1["TotalAmountBank"].var()
# Out:
# 3893436175.9907765

# %%
df1["TotalAmountBank"].kurt()
# Out:
# -1.489411767941925

# %%
df1["TotalAmountBank"].skew()
# Out:
# -0.14110871094154384

# %%
df1["TotalAmountBank"].quantile([.1, .2,.25, .3, .4, .5, .6, .7, .8, .9, .99])
# Out:
# 0.10         0.0000
# 0.20         0.0000
# 0.25         0.0000
# 0.30         0.0000
# 0.40     73080.9080
# 0.50     97198.5400
# 0.60    110138.9260
# 0.70    122029.8700
# 0.80    133710.3580
# 0.90    149244.7920
# 0.99    185967.9854
# Name: TotalAmountBank, dtype: float64

# %%
df1.describe().T
# Out:
#                    count          mean           std          min  \
# CustomerId       10000.0  1.569094e+07  7.193619e+04  15565701.00
# RowNumber        10000.0  5.000500e+03  2.886896e+03         1.00
# CreditScore      10000.0  6.505288e+02  9.665330e+01       350.00
# age_in_year      10000.0  3.892180e+01  1.048781e+01        18.00
# Tenure           10000.0  5.012800e+00  2.892174e+00         0.00
# TotalAmountBank  10000.0  7.648589e+04  6.239741e+04         0.00
# NumOfProducts    10000.0  1.530200e+00  5.816544e-01         1.00
# HasCrCard        10000.0  7.055000e-01  4.558405e-01         0.00
# IsActiveMember   10000.0  5.151000e-01  4.997969e-01         0.00
# EstimatedSalary  10000.0  1.000902e+05  5.751049e+04        11.58
# Exited           10000.0  2.037000e-01  4.027686e-01         0.00
# Salary INR       10000.0  7.706948e+06  4.428308e+06       891.66
# Balance_Salary   10000.0  1.765761e+05  8.539755e+04        90.07
#
# ...

# %%
df1.describe(percentiles=[.1, .2,.25, .3, .4, .5, .6, .7, .8, .9, .99]).T
# Out:
#                    count          mean           std          min  \
# CustomerId       10000.0  1.569094e+07  7.193619e+04  15565701.00
# RowNumber        10000.0  5.000500e+03  2.886896e+03         1.00
# CreditScore      10000.0  6.505288e+02  9.665330e+01       350.00
# age_in_year      10000.0  3.892180e+01  1.048781e+01        18.00
# Tenure           10000.0  5.012800e+00  2.892174e+00         0.00
# TotalAmountBank  10000.0  7.648589e+04  6.239741e+04         0.00
# NumOfProducts    10000.0  1.530200e+00  5.816544e-01         1.00
# HasCrCard        10000.0  7.055000e-01  4.558405e-01         0.00
# IsActiveMember   10000.0  5.151000e-01  4.997969e-01         0.00
# EstimatedSalary  10000.0  1.000902e+05  5.751049e+04        11.58
# Exited           10000.0  2.037000e-01  4.027686e-01         0.00
# Salary INR       10000.0  7.706948e+06  4.428308e+06       891.66
# Balance_Salary   10000.0  1.765761e+05  8.539755e+04        90.07
#
# ...

# %%
df1.describe(include=["object"]).T
# Out:
#                   count unique          top  freq
# Surname           10000   2932        Smith    32
# Geography         10000      3       France  5014
# Gender            10000      2         Male  5457
# income_group1     10000      2  High Income  7547
# income_group2     10000      3         High  5010
# income_group_cat  10000      3         High  5010

# %%
df1.describe(include=["object", "int"]).T
# Out:
#                     count unique          top  freq           mean  \
# CustomerId        10000.0    NaN          NaN   NaN  15690940.5694
# RowNumber         10000.0    NaN          NaN   NaN         5000.5
# Surname             10000   2932        Smith    32            NaN
# CreditScore       10000.0    NaN          NaN   NaN       650.5288
# Geography           10000      3       France  5014            NaN
# Gender              10000      2         Male  5457            NaN
# age_in_year       10000.0    NaN          NaN   NaN        38.9218
# Tenure            10000.0    NaN          NaN   NaN         5.0128
# NumOfProducts     10000.0    NaN          NaN   NaN         1.5302
# HasCrCard         10000.0    NaN          NaN   NaN         0.7055
# IsActiveMember    10000.0    NaN          NaN   NaN         0.5151
# Exited            10000.0    NaN          NaN   NaN         0.2037
# income_group1       10000      2  High Income  7547            NaN
# ...

# %%
df1.groupby(["Geography"]).mean()
# Out:
#              CustomerId    RowNumber  CreditScore  age_in_year    Tenure  \
# Geography
# France     1.569065e+07  5025.228560   649.668329    38.511767  5.004587
# Germany    1.569056e+07  5000.278996   651.453567    39.771622  5.009964
# Spain      1.569192e+07  4950.667743   651.333872    38.890997  5.032297
#
#            TotalAmountBank  NumOfProducts  HasCrCard  IsActiveMember  \
# Geography
# France        62092.636516       1.530913   0.706621        0.516753
# Germany      119730.116134       1.519729   0.713830        0.497409
# Spain         61818.147763       1.539362   0.694792        0.529673
#
#            EstimatedSalary    Exited    Salary INR  Balance_Salary
# Geography
# France        99899.180814  0.161548  7.692237e+06   161991.817329
# Germany      101113.435102  0.324432  7.785735e+06   220843.551236
# Spain         99440.572281  0.166734  7.656924e+06   161258.720044

# %%
df1.groupby(["Geography"]).min()
# Out:
#            CustomerId  RowNumber  Surname  CreditScore  Gender  age_in_year  \
# Geography
# France       15565714          1    Abbie          350  Female           18
# Germany      15565779          8  Abdulov          350  Female           18
# Spain        15565701          2    Abazu          350  Female           18
#
#            Tenure  TotalAmountBank  NumOfProducts  HasCrCard  IsActiveMember  \
# Geography
# France          0             0.00              1          0               0
# Germany         0         27288.43              1          0               0
# Spain           0             0.00              1          0               0
#
#            EstimatedSalary  Exited  Salary INR  Balance_Salary income_group1  \
# Geography
# France               90.07       0     6935.39           90.07   High Income
# Germany              11.58       0      891.66        30263.56   High Income
# Spain               417.41       0    32140.57          417.41   High Income
#
# ...

# %%
df1.groupby(["Geography"])["CreditScore"].min()
# Out:
# Geography
# France     350
# Germany    350
# Spain      350
# Name: CreditScore, dtype: int64

# %%
df1.groupby(["Geography"]).agg({"CreditScore": ["count", "min", "max", "mean"]})
# Out:
#           CreditScore
#                 count  min  max        mean
# Geography
# France           5014  350  850  649.668329
# Germany          2509  350  850  651.453567
# Spain            2477  350  850  651.333872

# %%
df1.groupby(["Geography"]).agg({"TotalAmountBank": ["count", "min", "max", "mean"]})
# Out:
#           TotalAmountBank
#                     count       min        max           mean
# Geography
# France               5014      0.00  238387.56   62092.636516
# Germany              2509  27288.43  214346.96  119730.116134
# Spain                2477      0.00  250898.09   61818.147763

# %%
df1.groupby(["Geography"]).agg({"TotalAmountBank": ["count", "min", "max", "mean"],
                               "age_in_year":["min", "max", "mean", "std"]})
# Out:
#           TotalAmountBank                                     age_in_year      \
#                     count       min        max           mean         min max
# Geography
# France               5014      0.00  238387.56   62092.636516          18  92
# Germany              2509  27288.43  214346.96  119730.116134          18  84
# Spain                2477      0.00  250898.09   61818.147763          18  88
#
#
#                 mean        std
# Geography
# France     38.511767  10.469459
# Germany    39.771622  10.519143
# Spain      38.890997  10.446119

# %%
df1.groupby(["Geography", "Gender"]).agg({"TotalAmountBank": ["count", "min", "max", "mean"],
                               "age_in_year":["min", "max", "mean", "std"]})
# Out:
#                  TotalAmountBank                                      \
#                            count       min        max           mean
# Geography Gender
# France    Female            2261      0.00  238387.56   60322.670159
#           Male              2753      0.00  212692.97   63546.284875
# Germany   Female            1193  32197.64  206868.78  119145.966471
#           Male              1316  27288.43  214346.96  120259.668222
# Spain     Female            1089      0.00  216109.88   59862.092534
#           Male              1388      0.00  250898.09   63352.833746
#
#                  age_in_year
#                          min max       mean        std
# Geography Gender
# France    Female          18  85  38.773994  10.685519
#           Male            18  92  38.296404  10.285569
# Germany   Female          18  77  40.154233  10.461002
#           Male            18  84  39.424772  10.563570
# Spain     Female          19  79  39.199265  10.469659
# ...

# %% [markdown]
# ### Joins

# %%
mydf=pd.DataFrame({"ID":[10, 11, 12, 11,14,15, 11],
             "Name":["Harry", "Dawn", "Gini", "Dawn", np.nan, "John", "Dawn"],
                  "marks":[89, 75, np.nan, 75, np.nan, 81,86]})

# %%
mydf1=pd.DataFrame({"ID":[18,20],
                   "Name": ["Durba", "Aura"],
                   "marks":[88,77]})

# %%
mydf.append(mydf1, ignore_index=True)
# Out:
# C:\Users\Archit\AppData\Local\Temp/ipykernel_4672/3446724085.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mydf.append(mydf1, ignore_index=True)
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini    NaN
# 3  11   Dawn   75.0
# 4  14    NaN    NaN
# 5  15   John   81.0
# 6  11   Dawn   86.0
# 7  18  Durba   88.0
# 8  20   Aura   77.0

# %%
pd.concat([mydf, mydf1], axis=0, ignore_index=True)
# Out:
#    ID   Name  marks
# 0  10  Harry   89.0
# 1  11   Dawn   75.0
# 2  12   Gini    NaN
# 3  11   Dawn   75.0
# 4  14    NaN    NaN
# 5  15   John   81.0
# 6  11   Dawn   86.0
# 7  18  Durba   88.0
# 8  20   Aura   77.0

# %%
pd.concat([mydf, mydf1], axis=1)
# Out:
#    ID   Name  marks    ID   Name  marks
# 0  10  Harry   89.0  18.0  Durba   88.0
# 1  11   Dawn   75.0  20.0   Aura   77.0
# 2  12   Gini    NaN   NaN    NaN    NaN
# 3  11   Dawn   75.0   NaN    NaN    NaN
# 4  14    NaN    NaN   NaN    NaN    NaN
# 5  15   John   81.0   NaN    NaN    NaN
# 6  11   Dawn   86.0   NaN    NaN    NaN

# %%
mydf2=pd.DataFrame({"ID":[10, 11,14, 11],
                   "income":[120, 355, 8765, 566]})

# %%
# pd.merge(left, right, on, how) 
left=pd.merge(mydf, mydf2, on=["ID"], how="left")
left
# Out:
#    ID   Name  marks  income
# 0  10  Harry   89.0   120.0
# 1  11   Dawn   75.0   355.0
# 2  11   Dawn   75.0   566.0
# 3  12   Gini    NaN     NaN
# 4  11   Dawn   75.0   355.0
# 5  11   Dawn   75.0   566.0
# 6  14    NaN    NaN  8765.0
# 7  15   John   81.0     NaN
# 8  11   Dawn   86.0   355.0
# 9  11   Dawn   86.0   566.0

# %%
mydf.to_excel("fgh.xlsx")

# %%
os.getcwd()
# Out:
# 'D:\\Training\\PGA_A\\PGA23\\ML\\EDA'

# %%
inn=pd.merge(mydf, mydf2, on=["ID"], how="inner")
inn
# Out:
#    ID   Name  marks  income
# 0  10  Harry   89.0     120
# 1  11   Dawn   75.0     355
# 2  11   Dawn   75.0     566
# 3  11   Dawn   75.0     355
# 4  11   Dawn   75.0     566
# 5  11   Dawn   86.0     355
# 6  11   Dawn   86.0     566
# 7  14    NaN    NaN    8765

# %%
right=pd.merge(mydf, mydf2, on=["ID"], how="right")
right
# Out:
#    ID   Name  marks  income
# 0  10  Harry   89.0     120
# 1  11   Dawn   75.0     355
# 2  11   Dawn   75.0     355
# 3  11   Dawn   86.0     355
# 4  14    NaN    NaN    8765
# 5  11   Dawn   75.0     566
# 6  11   Dawn   75.0     566
# 7  11   Dawn   86.0     566

# %%
full=pd.merge(mydf, mydf2, on=["ID"], how="outer")
full
# Out:
#    ID   Name  marks  income
# 0  10  Harry   89.0   120.0
# 1  11   Dawn   75.0   355.0
# 2  11   Dawn   75.0   566.0
# 3  11   Dawn   75.0   355.0
# 4  11   Dawn   75.0   566.0
# 5  11   Dawn   86.0   355.0
# 6  11   Dawn   86.0   566.0
# 7  12   Gini    NaN     NaN
# 8  14    NaN    NaN  8765.0
# 9  15   John   81.0     NaN
